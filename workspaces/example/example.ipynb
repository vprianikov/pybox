# %%
# %reload_ext dotenv
# %dotenv .env.shared
# %dotenv .env

# %%
from pathlib import Path

tmp = Path("tmp")
tmp.mkdir(parents=True, exist_ok=True)

f"Для временных файлов используется директория {tmp.absolute()}"

# %%
from os import environ

test = environ.get("TEST")
if not test:
    raise RuntimeError('Не задана переменная окружения "TEST"')

f"{test}"
